# %%
import numpy as np

# %%
A = np.array([[2.1,  7.9, 8.4],
              [3.0,  4.5, 2.3],
              [12.2, 6.6, 8.9],
              [1.8,  1.,  8.2]])

# %% [markdown]
# ![image.png](attachment:db734978-37c0-4065-aadf-c5c28b78fa2c.png)

# %%
A = np.array([
    [1, 2],
    [5, 6],
    [7, 8]
])

# %%
v = np.array([3, 4]).reshape(-1, 1)

# %%
A @ v
# Out:
# array([[11],
#        [39],
#        [53]])

# %% [markdown]
# we have a vector [3, 4]
#
# multiply the vector values/elements/weights with the DATA (A)
#
# A.v = LINEAR COMBINATION of columns in A with the weights in v

# %% [markdown]
# #### Ex 02

# %%
x = np.random.normal(10, 2, 100)

y = x * 1.5 + np.random.normal(25, 5, 100)
z = x * 2   + np.random.normal(0, 1, 100)

# %%
x
# Out:
# array([ 9.40229719, 10.16171901, 10.73168108,  7.88489005,  8.95308374,
#        13.57767146, 10.09008308,  8.61892484, 10.12870072,  9.76481616,
#         6.02562619, 10.27719857, 10.65018564, 12.03939294, 11.95626302,
#         8.72987343,  9.37061625,  9.77934738, 10.4136114 , 13.30412461,
#        10.42687159,  9.8952944 , 11.29828112, 11.6602946 ,  8.78908551,
#         9.8622899 , 11.26754299,  4.82152977,  8.96785391, 11.33304583,
#        10.73293448,  8.51943461, 11.53444652,  6.88169175, 11.16734781,
#         9.82273055, 10.53009331, 11.76529201, 11.48168668,  7.59750342,
#         9.21692345, 12.61062096, 11.97495878, 10.76119953, 10.88311146,
#         9.75983165, 10.70246742,  6.83904891,  9.11170139,  9.45416423,
#         7.55534718, 13.48327893,  7.58150575,  8.3665818 ,  7.6916518 ,
#         8.1539468 ,  9.14875639, 11.42674539, 12.38813153,  8.3756538 ,
#         9.79371521,  9.15391893, 13.01510676,  8.96422564, 11.46104463,
# ...

# %%
y
# Out:
# array([35.76456083, 35.85455232, 45.96229346, 40.15532757, 41.10275954,
#        43.62095385, 44.9373705 , 40.29699429, 43.72216177, 36.5286753 ,
#        29.98483957, 32.50928821, 37.63603334, 38.3691384 , 28.46437604,
#        39.79938491, 36.20196409, 33.21559957, 41.07430258, 50.44703037,
#        41.65903052, 33.46907528, 48.1422665 , 38.9117334 , 42.16421733,
#        49.88471781, 38.1705884 , 39.23786075, 46.26176011, 36.2596595 ,
#        37.46685792, 32.79141394, 41.41920326, 36.83305225, 43.38887499,
#        31.50514565, 44.21306376, 44.51127572, 38.71725746, 40.34946749,
#        48.56576528, 46.99670066, 50.83413353, 42.32280803, 49.98223688,
#        39.43104095, 46.60002911, 34.25489108, 35.8849982 , 31.48062283,
#        39.2457323 , 39.25475552, 35.23034575, 34.65051298, 35.91295478,
#        35.92123688, 40.68532602, 43.66848719, 41.03717911, 41.48548204,
#        46.4808397 , 35.4561466 , 52.16534306, 39.96935245, 45.24412364,
# ...

# %%
z
# Out:
# array([18.37640247, 22.80650242, 22.28279044, 16.90401313, 20.03180163,
#        24.02471179, 20.78533665, 17.61841719, 21.08263683, 18.88339282,
#        12.25011228, 23.55569126, 23.13785466, 24.09468876, 23.59309666,
#        16.79081315, 20.27470842, 20.56733532, 21.77609281, 28.97416466,
#        20.08148197, 19.21924597, 22.4722496 , 22.30042302, 17.96279418,
#        21.50134662, 23.01994526, 10.16850127, 18.49253108, 21.26006858,
#        19.36732673, 18.62264044, 21.1796839 , 13.25975579, 20.76291083,
#        19.89735454, 20.81120841, 24.35256646, 22.10508809, 15.77984496,
#        17.82038109, 25.32309942, 24.0062525 , 21.06952516, 23.0057904 ,
#        19.27698115, 21.01026204, 14.44912995, 18.31160262, 18.99369474,
#        15.39994531, 25.94203873, 15.80986634, 16.67523419, 16.42925772,
#        17.33852759, 18.71143737, 22.69095539, 25.42349859, 17.84818246,
#        19.66595974, 17.56432955, 25.72746897, 17.45282076, 22.2930675 ,
# ...

# %%
[x, y, z]
# Out:
# [array([ 9.40229719, 10.16171901, 10.73168108,  7.88489005,  8.95308374,
#         13.57767146, 10.09008308,  8.61892484, 10.12870072,  9.76481616,
#          6.02562619, 10.27719857, 10.65018564, 12.03939294, 11.95626302,
#          8.72987343,  9.37061625,  9.77934738, 10.4136114 , 13.30412461,
#         10.42687159,  9.8952944 , 11.29828112, 11.6602946 ,  8.78908551,
#          9.8622899 , 11.26754299,  4.82152977,  8.96785391, 11.33304583,
#         10.73293448,  8.51943461, 11.53444652,  6.88169175, 11.16734781,
#          9.82273055, 10.53009331, 11.76529201, 11.48168668,  7.59750342,
#          9.21692345, 12.61062096, 11.97495878, 10.76119953, 10.88311146,
#          9.75983165, 10.70246742,  6.83904891,  9.11170139,  9.45416423,
#          7.55534718, 13.48327893,  7.58150575,  8.3665818 ,  7.6916518 ,
#          8.1539468 ,  9.14875639, 11.42674539, 12.38813153,  8.3756538 ,
#          9.79371521,  9.15391893, 13.01510676,  8.96422564, 11.46104463,
# ...

# %%
np.cov([x, y, z])
# Out:
# array([[ 3.31056252,  4.19359057,  6.17319177],
#        [ 4.19359057, 29.44524899,  8.47758568],
#        [ 6.17319177,  8.47758568, 12.4672011 ]])
